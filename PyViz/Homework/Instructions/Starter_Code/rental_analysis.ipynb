# %% [markdown]
# # Toronto Dwellings Analysis
#
# In this assignment, you will perform fundamental analysis for the Toronto dwellings market to allow potential real estate investors to choose rental investment properties.

# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api = os.getenv("mapbox")

# %% [markdown]
# ## Load Data

# %%
# Read the census data into a Pandas DataFrame
file_path = Path("Data/toronto_neighbourhoods_census_data.csv")
to_data = pd.read_csv(file_path, index_col="year")
to_data.head()
# Out:
#                      neighbourhood  single_detached_house  \
# year
# 2001               Agincourt North                   3715
# 2001  Agincourt South-Malvern West                   3250
# 2001                     Alderwood                   3175
# 2001                         Annex                   1060
# 2001             Banbury-Don Mills                   3615
#
#       apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# year
# 2001                         1480                 0                 1055
# 2001                         1835                 0                  545
# 2001                          315                 0                  470
# 2001                         6090                 5                 1980
# 2001                         4465                 0                  240
#
#       row_house  duplex  apartment_five_storeys_less  other_house  \
# year
# 2001       1295     195                          185            5
# 2001        455     105                          425            0
# 2001         50     185                          370            0
# 2001        605     275                         3710          165
# 2001        380      15                         1360            0
#
#       average_house_value  shelter_costs_owned  shelter_costs_rented
# year
# 2001               200388                  810                   870
# 2001               203047                  806                   892
# 2001               259998                  817                   924
# 2001               453850                 1027                  1378
# 2001               371864                 1007                  1163

# %% [markdown]
# - - -

# %% [markdown]
# ## Dwelling Types Per Year
#
# In this section, you will calculate the number of dwelling types per year. Visualize the results using bar charts and the Pandas plot function.
#
# **Hint:** Use the Pandas `groupby` function.
#
# **Optional challenge:** Plot each bar chart in a different color.

# %%
# Calculate the sum number of dwelling types units per year (hint: use groupby)
dwelling_group = to_data.groupby(["year"])["single_detached_house", 
                          "apartment_five_storeys_plus", 
                          "movable_dwelling", 
                          "semi_detached_house",
                          "row_house", "duplex", 
                          "apartment_five_storeys_less", 
                          "other_house"].sum()
dwelling_group.head()
# Out:
#       single_detached_house  apartment_five_storeys_plus  movable_dwelling  \
# year
# 2001                 300930                       355015                75
# 2006                 266860                       379400               165
# 2011                 274940                       429220               100
# 2016                 269680                       493270                95
#
#       semi_detached_house  row_house  duplex  apartment_five_storeys_less  \
# year
# 2001                90995      52355   23785                       116900
# 2006                69430      54690   44095                       162850
# 2011                72480      60355   44750                       163895
# 2016                71200      61565   48585                       165575
#
#       other_house
# year
# 2001         3040
# 2006         1335
# 2011         2165
# 2016         2845

# %%
# Save the dataframe as a csv file
dwelling_groupcsv = dwelling_group.to_csv()

# %%
# Helper create_bar_chart function
def create_bar_chart(data, title, xlabel, ylabel, color):
    dwelling_group.loc[data].plot.bar(y='value', color=color, rot=90, subplots=True, sharex=True),
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# Create a bar chart per year to show the number of dwelling types

# Bar chart for 2001
create_bar_chart(2001, 'Dwelling types in Toronto for 2001', "Dwelling Types", "Dwelling Unit", "darkorange")

# %%
# Bar chart for 2006
create_bar_chart(2006, 'Dwelling types in Toronto for 2006', "Dwelling Types", "Dwelling Unit", "darkblue")

# %%
# Bar chart for 2011
create_bar_chart(2011, 'Dwelling types in Toronto for 2011', "Dwelling Types", "Dwelling Unit", "darkgray")

# %%
# Bar chart for 2016
create_bar_chart(2016, 'Dwelling types in Toronto for 2016', "Dwelling Types", "Dwelling Unit", "darkgreen")

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Monthly Shelter Costs in Toronto Per Year
#
# In this section, you will calculate the average monthly shelter costs for owned and rented dwellings and the average house value for each year. Plot the results as a line chart.
#
# **Optional challenge:** Plot each line chart in a different color.

# %%
# Calculate the average monthly shelter costs for owned and rented dwellings
dwelling_group2 = to_data.groupby(["year"])["shelter_costs_owned", "shelter_costs_rented"].mean()
dwelling_group2.head()
# Out:
#       shelter_costs_owned  shelter_costs_rented
# year
# 2001           846.878571           1085.935714
# 2006          1316.800000            925.414286
# 2011          1448.214286           1019.792857
# 2016          1761.314286           1256.321429

# %%
# Helper create_line_chart function
def create_line_chart(data, title, xlabel, ylabel, color):
    dwelling_group2.plot.line(y=data, color=color, rot=0, subplots=True)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# Create two line charts, one to plot the monthly shelter costs for owned dwelleing and other for rented dwellings per year

# Line chart for owned dwellings
create_line_chart('shelter_costs_owned', 'Average Monthly Shelter Costs for Owned Dwellings', 'Year', 'Ave. Monthly Shelter Cost', 'darkblue')

# Line chart for rented dwellings
create_line_chart('shelter_costs_rented', 'Average Monthly Shelter Costs for Rented Dwellings', 'Year', 'Ave. Monthly Shelter Cost', 'darkorange')

# %% [markdown]
# ## Average House Value per Year
#
# In this section, you want to determine the average house value per year. An investor may want to understand better the sales price of the rental property over time. For example, a customer will want to know if they should expect an increase or decrease in the property value over time so they can determine how long to hold the rental property. You will visualize the `average_house_value` per year as a bar chart.

# %%
# Calculate the average house value per year

dwelling_group3 = to_data.groupby(["year"])["average_house_value"].mean()
dwelling_group3.head()
# Out:
# year
# 2001    289882.885714
# 2006    424059.664286
# 2011    530424.721429
# 2016    664068.328571
# Name: average_house_value, dtype: float64

# %%
# Plot the average house value per year as a line chart
dwelling_group3.plot()

# %% [markdown]
# - - -

# %% [markdown]
# ## Average House Value by Neighbourhood
#
# In this section, you will use `hvplot` to create an interactive visualization of the average house value with a dropdown selector for the neighbourhood.
#
# **Hint:** It will be easier to create a new DataFrame from grouping the data and calculating the mean house values for each year and neighbourhood.

# %%
# Create a new DataFrame with the mean house values by neighbourhood per year
new_df = to_data[['neighbourhood','average_house_value']]
new_df.head()
# Out:
#                      neighbourhood  average_house_value
# year
# 2001               Agincourt North               200388
# 2001  Agincourt South-Malvern West               203047
# 2001                     Alderwood               259998
# 2001                         Annex               453850
# 2001             Banbury-Don Mills               371864

# %%
# Use hvplot to create an interactive line chart of the average house value per neighbourhood
# The plot should have a dropdown selector for the neighbourhood
from panel.interact import interact


new_df.hvplot(kind='line', x="year",
             groupby='neighbourhood',
             y="average_house_value",
             title="Average House Value per Neighbourhood", yformatter='%.0f'
)
# Out:
# :DynamicMap   [neighbourhood]
#    :Curve   [year]   (average_house_value)

# %% [markdown]
# ## Number of Dwelling Types per Year
#
# In this section, you will use `hvplot` to create an interactive visualization of the average number of dwelling types per year with a dropdown selector for the neighbourhood.

# %%
# Fetch the data of all dwelling types per year
new_table = to_data.reset_index()
new_table.head(10)
# Out:
#    year                 neighbourhood  single_detached_house  \
# 0  2001               Agincourt North                   3715
# 1  2001  Agincourt South-Malvern West                   3250
# 2  2001                     Alderwood                   3175
# 3  2001                         Annex                   1060
# 4  2001             Banbury-Don Mills                   3615
# 5  2001                Bathurst Manor                   2405
# 6  2001           Bay Street Corridor                     10
# 7  2001               Bayview Village                   2170
# 8  2001         Bayview Woods-Steeles                   1650
# 9  2001          Bedford Park-Nortown                   4985
#
#    apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# 0                         1480                 0                 1055
# 1                         1835                 0                  545
# 2                          315                 0                  470
# 3                         6090                 5                 1980
# 4                         4465                 0                  240
# 5                         1550                 0                  130
# 6                         7575                 0                    0
# 7                          630                 0                  170
# 8                         1715                 0                  925
# 9                         2080                 0                   45
#
#    row_house  duplex  apartment_five_storeys_less  other_house  \
# 0       1295     195                          185            5
# 1        455     105                          425            0
# 2         50     185                          370            0
# 3        605     275                         3710          165
# 4        380      15                         1360            0
# 5        130     375                          745            0
# 6         15       0                          240            0
# 7        765      15                          640            0
# 8        105      10                          170            5
# 9         40     210                         1235           15
#
#    average_house_value  shelter_costs_owned  shelter_costs_rented
# 0               200388                  810                   870
# 1               203047                  806                   892
# 2               259998                  817                   924
# 3               453850                 1027                  1378
# 4               371864                 1007                  1163
# 5               304749                  843                  1052
# 6               257404                 1218                  1142
# 7               327644                 1197                  1164
# 8               343535                 1212                  1018
# 9               565304                  933                  1491

# %%
# Use hvplot to create an interactive bar chart of the number of dwelling types per neighbourhood
# The plot should have a dropdown selector for the neighbourhood
new_table1=new_table.drop(['average_house_value', 'shelter_costs_owned', 'shelter_costs_rented'], axis=1)

new_table1.hvplot(x= 'year', xlabel = 'Year', ylabel = 'Dwelling Type Units', kind = 'bar', groupby = 'neighbourhood', stacked=False, height=550, width= 800, rot=90)
# Out:
# :DynamicMap   [neighbourhood]
#    :Bars   [year,Variable]   (value)

# %% [markdown]
# - - -

# %% [markdown]
# ## The Top 10 Most Expensive Neighbourhoods
#
# In this section, you will need to calculate the house value for each neighbourhood and then sort the values to obtain the top 10 most expensive neighbourhoods on average. Plot the results as a bar chart.

# %%
# Getting the data from the top 10 expensive neighbourhoods
#to_data.head()
to_data2 = to_data.groupby(['neighbourhood'])['average_house_value'].sum()
to_data2.nlargest(10)
# Out:
# neighbourhood
# Bridle Path-Sunnybrook-York Mills    6105943
# Forest Hill South                    4783970
# Lawrence Park South                  4376111
# Rosedale-Moore Park                  4374560
# St.Andrew-Windfields                 3996428
# Casa Loma                            3924257
# Bedford Park-Nortown                 3721661
# Forest Hill North                    3406722
# Kingsway South                       3372937
# Yonge-St.Clair                       3252881
# Name: average_house_value, dtype: int64

# %%
# Plotting the data from the top 10 expensive neighbourhoods
to_data2.nlargest(10).hvplot.bar(rot=60, height=600, yformatter='%.0f')
# Out:
# :Bars   [neighbourhood]   (average_house_value)

# %% [markdown]
# - - -

# %% [markdown]
# ## Neighbourhood Map
#
# In this section, you will read in neighbourhoods location data and build an interactive map with the average house value per neighbourhood. Use a `scatter_mapbox` from Plotly express to create the visualization. Remember, you will need your Mapbox API key for this.

# %% [markdown]
# ### Load Location Data

# %%
# Load neighbourhoods coordinates data
file_path = Path("Data/toronto_neighbourhoods_coordinates.csv")
df_neighbourhood_locations = pd.read_csv(file_path)
df_neighbourhood_locations.head(5)
# Out:
#                   neighbourhood        lat        lon
# 0               Agincourt North  43.805441 -79.266712
# 1  Agincourt South-Malvern West  43.788658 -79.265612
# 2                     Alderwood  43.604937 -79.541611
# 3                         Annex  43.671585 -79.404001
# 4             Banbury-Don Mills  43.737657 -79.349718

# %% [markdown]
# ### Data Preparation
#
# You will need to join the location data with the mean values per neighbourhood.
#
# 1. Calculate the mean values for each neighbourhood.
#
# 2. Join the average values with the neighbourhood locations.

# %%
# Calculate the mean values for each neighborhood
# YOUR CODE HERE!
data_prep = to_data.groupby(['neighbourhood'])["single_detached_house", 
                          "apartment_five_storeys_plus", 
                          "movable_dwelling", 
                          "semi_detached_house",
                          "row_house", "duplex", 
                          "apartment_five_storeys_less", 
                          "other_house", "average_house_value",
                          "shelter_costs_owned",
                          "shelter_costs_rented"].mean()

data_prep = data_prep.reset_index()
data_prep.head()
# Out:
#                   neighbourhood  single_detached_house  \
# 0               Agincourt North                3435.00
# 1  Agincourt South-Malvern West                2897.50
# 2                     Alderwood                2903.75
# 3                         Annex                 751.25
# 4             Banbury-Don Mills                3572.50
#
#    apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# 0                      1947.50              2.50               863.75
# 1                      2180.00              1.25               375.00
# 2                       302.50              1.25               503.75
# 3                      7235.00              1.25              1375.00
# 4                      5388.75              1.25               273.75
#
#    row_house  duplex  apartment_five_storeys_less  other_house  \
# 0    1406.25  512.50                       547.50        10.00
# 1     456.25  523.75                       628.75        32.50
# 2      76.25  302.50                       502.50         1.25
# 3     613.75  355.00                      4605.00        83.75
# 4     626.25   32.50                      1340.00         0.00
#
#    average_house_value  shelter_costs_owned  shelter_costs_rented
# 0             329811.5              1109.00                983.50
# 1             334189.0              1131.25                985.00
# 2             427922.5              1166.75               1003.25
# 3             746977.0              1692.75               1315.25
# 4             612039.0              1463.50               1242.75

# %%
# Join the average values with the neighbourhood locations
merge_data = pd.merge(left=df_neighbourhood_locations, right=data_prep)
merge_data.head()
# Out:
#                   neighbourhood        lat        lon  single_detached_house  \
# 0               Agincourt North  43.805441 -79.266712                3435.00
# 1  Agincourt South-Malvern West  43.788658 -79.265612                2897.50
# 2                     Alderwood  43.604937 -79.541611                2903.75
# 3                         Annex  43.671585 -79.404001                 751.25
# 4             Banbury-Don Mills  43.737657 -79.349718                3572.50
#
#    apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# 0                      1947.50              2.50               863.75
# 1                      2180.00              1.25               375.00
# 2                       302.50              1.25               503.75
# 3                      7235.00              1.25              1375.00
# 4                      5388.75              1.25               273.75
#
#    row_house  duplex  apartment_five_storeys_less  other_house  \
# 0    1406.25  512.50                       547.50        10.00
# 1     456.25  523.75                       628.75        32.50
# 2      76.25  302.50                       502.50         1.25
# 3     613.75  355.00                      4605.00        83.75
# 4     626.25   32.50                      1340.00         0.00
#
#    average_house_value  shelter_costs_owned  shelter_costs_rented
# 0             329811.5              1109.00                983.50
# 1             334189.0              1131.25                985.00
# 2             427922.5              1166.75               1003.25
# 3             746977.0              1692.75               1315.25
# 4             612039.0              1463.50               1242.75

# %% [markdown]
# ### Mapbox Visualization
#
# Plot the average values per neighbourhood using a Plotly express `scatter_mapbox` visualization.

# %%
# Create a scatter mapbox to analyze neighbourhood info
px.set_mapbox_access_token(map_box_api)

# %%
neighbourhood_plot = px.scatter_mapbox(
    merge_data,
    lat='lat',
    lon='lon',
    size='average_house_value',
    hover_name="neighbourhood",
    hover_data = [
        "shelter_costs_owned",
        "shelter_costs_rented",
        "single_detached_house",
        "apartment_five_storeys_plus",
        "movable_dwelling",
        "semi_detached_house",
        "row_house",
        "duplex",
        "apartment_five_storeys_less",
        "other_house"
    ],
    color='neighbourhood',
    color_continuous_scale=px.colors.cyclical.IceFire,
    title="Average House Values in Toronto",
    zoom=10,
    width=1800,
)


single_detached_plot = px.scatter_mapbox(
    merge_data,
    lat='lat',
    lon='lon',
    size='single_detached_house',
    hover_name="neighbourhood",
    hover_data = [
        "shelter_costs_owned",
        "shelter_costs_rented",
        "single_detached_house",
        "apartment_five_storeys_plus",
        "movable_dwelling",
        "semi_detached_house",
        "row_house",
        "duplex",
        "apartment_five_storeys_less",
        "other_house"
    ],
    color='neighbourhood',
    color_continuous_scale=px.colors.cyclical.IceFire,
    title='Single Detached Spatial',
    zoom=10,
    width=1500,
)
neighbourhood_column = pn.Column('## Neighbourhood Geo Plot', neighbourhood_plot)
dwelling_plot = pn.Column('## Dwelling Geo Plot', single_detached_plot)

real_estate_dashboard = pn.Tabs(
    (
       "House Value",
       neighbourhood_column
    ),
    (
       'Dwelling',
       single_detached_plot
    )
)

real_estate_dashboard
# Out:
# Tabs
#     [0] Column
#         [0] Markdown(str)
#         [1] Plotly(Figure)
#     [1] Plotly(Figure, name='Dwelling')

# %% [markdown]
# ## Cost Analysis - Optional Challenge
#
# In this section, you will use Plotly express to a couple of plots that investors can interactively filter and explore various factors related to the house value of the Toronto's neighbourhoods.
#
# ### Create a bar chart row facet to plot the average house values for all Toronto's neighbourhoods per year

# %%
# YOUR CODE HERE!

fig = px.bar(to_data, x="neighbourhood", y="average_house_value", color="average_house_value", facet_row=to_data.index, height=1000, 
             title = 'Average House Values in Toronto per Neighbourhood')
fig.show()

# %% [markdown]
# ### Create a sunburst chart to conduct a costs analysis of most expensive neighbourhoods in Toronto per year

# %%
#calling the dataset to be used
indexed_df1 = to_data.reset_index()
#trying to group and sort on different columns
df1 = indexed_df1.groupby(['year'])
df2 = df1.apply(lambda x: x.sort_values(['average_house_value'], ascending = False))
#resetting the new dataframe
df3 = df2.drop(columns='year').reset_index().drop(columns='level_1')
#the 10 most expensive neighbourhoods per year
df4 = df3.groupby('year').head(10)
df4
# Out:
#      year                      neighbourhood  single_detached_house  \
# 0    2001  Bridle Path-Sunnybrook-York Mills                   2275
# 1    2001                  Forest Hill South                   1815
# 2    2001                Lawrence Park South                   3590
# 3    2001                Rosedale-Moore Park                   2610
# 4    2001               St.Andrew-Windfields                   3275
# 5    2001                          Casa Loma                   1035
# 6    2001               Bedford Park-Nortown                   4985
# 7    2001                  Forest Hill North                   1565
# 8    2001                     Kingsway South                   2370
# 9    2001                     Yonge-St.Clair                    670
# 140  2006  Bridle Path-Sunnybrook-York Mills                   2205
# 141  2006                  Forest Hill South                   1740
# 142  2006                Lawrence Park South                   3415
# 143  2006                Rosedale-Moore Park                   2450
# 144  2006               St.Andrew-Windfields                   3095
# 145  2006                          Casa Loma                    875
# 146  2006               Bedford Park-Nortown                   4785
# 147  2006                  Forest Hill North                   1450
# 148  2006                     Kingsway South                   2275
# 149  2006                     Yonge-St.Clair                    540
# 280  2011  Bridle Path-Sunnybrook-York Mills                   2285
# 281  2011                  Forest Hill South                   1730
# 282  2011                Lawrence Park South                   3465
# 283  2011                Rosedale-Moore Park                   2485
# 284  2011               St.Andrew-Windfields                   3285
# 285  2011                          Casa Loma                    880
# 286  2011               Bedford Park-Nortown                   4870
# 287  2011                  Forest Hill North                   1470
# 288  2011                     Kingsway South                   2350
# 289  2011                     Yonge-St.Clair                    530
# 420  2016  Bridle Path-Sunnybrook-York Mills                   2275
# 421  2016                  Forest Hill South                   1685
# 422  2016                Lawrence Park South                   3420
# 423  2016                Rosedale-Moore Park                   2450
# 424  2016               St.Andrew-Windfields                   3245
# 425  2016                          Casa Loma                    875
# 426  2016               Bedford Park-Nortown                   4820
# 427  2016                  Forest Hill North                   1470
# 428  2016                     Kingsway South                   2310
# 429  2016                     Yonge-St.Clair                    520
#
#      apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# 0                            110                 0                   25
# 1                           2440                 5                   65
# 2                            570                 0                  170
# 3                           3880                 0                  520
# 4                           1455                 0                  220
# 5                           1700                 0                  415
# 6                           2080                 0                   45
# 7                           3380                 0                   10
# 8                            260                 0                   65
# 9                           3625                 0                  410
# 140                          145                 0                   35
# 141                         1835                 0                   50
# 142                          745                 0                  110
# 143                         4790                 0                  445
# 144                         1740                 0                  165
# 145                         2230                 0                  230
# 146                         1890                 0                   45
# 147                         3410                 0                   10
# 148                          560                 0                   60
# 149                         3785                 0                  390
# 280                          480                 0                   45
# 281                         1825                 0                   65
# 282                          855                 0                  115
# 283                         4905                 0                  495
# 284                         1740                 0                  180
# 285                         2630                 0                  245
# 286                         1960                 0                   40
# 287                         3350                 0                   15
# 288                          695                 0                   70
# 289                         4070                 0                  450
# 420                          590                 0                   40
# 421                         2025                 0                   65
# 422                          925                 0                  110
# 423                         4990                 0                  485
# 424                         1745                 0                  175
# 425                         2680                 0                  265
# 426                         1995                 0                   45
# 427                         3430                 0                   15
# 428                          790                 0                   70
# 429                         4315                 0                  450
#
#      row_house  duplex  apartment_five_storeys_less  other_house  \
# 0           15      10                           20            0
# 1           45      85                         1010           15
# 2           70     190                          845           40
# 3          225     290                         1735            0
# 4          555      45                          525            5
# 5          190     185                         1090            5
# 6           40     210                         1235           15
# 7            0       0                          485            5
# 8           45       0                          340           10
# 9          200     280                         1020           25
# 140         15      30                           10            0
# 141         50      70                         1015            0
# 142         25     250                         1025           10
# 143        245     330                         1685            5
# 144        560     105                          645            0
# 145        195     170                         1240            5
# 146         60     290                         1285          110
# 147         10     115                          375            0
# 148         50      25                          335            0
# 149        210     145                         1465            0
# 280        100      30                           50            0
# 281         45      75                         1035            0
# 282         25     230                          980           10
# 283        250     345                         1550            0
# 284        555     120                          580           10
# 285        220     140                         1215            0
# 286         65     335                         1320          115
# 287         25     105                          365            0
# 288         50      25                          335            0
# 289        220     135                         1380            0
# 420        230      30                           80            0
# 421         40      70                         1050            0
# 422         35     230                         1015            5
# 423        260     345                         1505            5
# 424        540     120                          595            5
# 425        200     155                         1225            0
# 426         65     315                         1260          115
# 427         30     110                          385            0
# 428         50      30                          335            0
# 429        220     130                         1370            0
#
#      average_house_value  shelter_costs_owned  shelter_costs_rented
# 0                 927466                 1983                  1790
# 1                 726664                 1001                  1469
# 2                 664712                 1021                  1630
# 3                 664476                 1219                  1540
# 4                 607040                 1055                  1551
# 5                 596077                 1241                  1500
# 6                 565304                  933                  1491
# 7                 517466                  940                  1428
# 8                 512334                 1362                  1340
# 9                 494098                 1091                  1351
# 140              1356757                 2170                  2167
# 141              1063011                 1781                  1094
# 142               972384                 1977                  1116
# 143               972039                 1868                  1332
# 144               888017                 1881                  1152
# 145               871981                 1819                  1356
# 146               826963                 1808                  1020
# 147               756983                 1731                  1027
# 148               749476                 1625                  1488
# 149               722799                 1638                  1192
# 280              1697067                 2387                  2388
# 281              1329642                 1959                  1206
# 282              1216283                 2174                  1230
# 283              1215852                 2054                  1468
# 284              1110755                 2069                  1270
# 285              1090696                 2001                  1494
# 286              1034387                 1988                  1124
# 287               946854                 1904                  1132
# 288               937464                 1787                  1640
# 289               904096                 1802                  1314
# 420              2124653                 2903                  2942
# 421              1664653                 2383                  1486
# 422              1522732                 2644                  1515
# 423              1522193                 2498                  1809
# 424              1390616                 2516                  1565
# 425              1365503                 2434                  1841
# 426              1295007                 2418                  1385
# 427              1185419                 2316                  1395
# 428              1173663                 2173                  2020
# 429              1131888                 2192                  1619

# %%
# Create the sunburst chart
import numpy as np
figure = px.sunburst(df4, path=['year', 'neighbourhood'], values='average_house_value',
                  color='shelter_costs_owned', hover_data=["shelter_costs_owned",
        "shelter_costs_rented",
        "single_detached_house",
        "apartment_five_storeys_plus",
        "movable_dwelling",
        "semi_detached_house",
        "row_house",
        "duplex",
        "apartment_five_storeys_less",
        "other_house"
    ],
                  title = 'Cost Analysis of Most Expensive Neighbourhoods in Toronto per Year',
                  color_continuous_scale='RdBu',
                  width = 1000,
                  height = 1000,
                  )
figure.show()
